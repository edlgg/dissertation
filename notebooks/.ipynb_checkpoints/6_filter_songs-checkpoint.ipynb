# %%
import mido
from utils import mido_setup, get_track_instrument_type
import os
import pandas
from collections import Counter

# %%
port = mido_setup()

filtered_path = "/Users/edlgg/repos/dissertation/midis/filtered_midis/"
guitar_bass_path = "/Users/edlgg/repos/dissertation/midis/guitar_bass_midis/"
song = mido.MidiFile(guitar_bass_path + "971113.mid")

# %%
def song_has_instruments(song, instruments):
    has_instruments = [False] * len(instruments)
    for i, instrument in enumerate(instruments):
        for track in song.tracks:
            type_ = get_track_instrument_type(track)
            if type_ == instrument:
                has_instruments[i] = True

    for instrument in has_instruments:
        if not instrument:
            return False
    return True

def test_song_has_instruments():
    song = mido.MidiFile(filtered_path + "971113.mid")
    instruments = ["Guitar", "Bass"]
    return song_has_instruments(song, instruments)
# test_song_has_instruments()

# %%
def delete_songs_without_instruments(path, instruments):
    for _, _, filenames in os.walk(path):
        for filename in filenames:
            try:
                song = mido.MidiFile(path + filename)
                print("Loading song: " + filename)
                if song_has_instruments(song, instruments):
                    os.rename(path + filename, guitar_bass_path + filename)
                    print("Moved song: " + filename)

                else:
                    print("Deleted song: " + filename)
                    os.remove(path + filename)
            except:
                print("Error loading: " + filename + " will delete")
                os.remove(path + filename)
# delete_songs_without_instruments(filtered_path, ["Guitar", "Bass"])

# %%
def remove_unused_instruments(initial_path, end_path):
    for _, _, filenames in os.walk(initial_path):
        for filename in filenames:
            try:
                song = mido.MidiFile(initial_path + filename)
                print("Loading song: " + filename)
                mid = mido.MidiFile()
                guitar_track = []
                bass_track = []
                for track in song.tracks:
                    type_ = get_track_instrument_type(track)
                    if type_ == "Guitar" and len(track) > len(guitar_track):
                        guitar_track = track
                    if type_ == "Bass" and len(track) > len(bass_track):
                        bass_track = track
                mid.tracks.append(guitar_track)
                mid.tracks.append(bass_track)
                mid.save(end_path + filename)
                os.remove(initial_path + filename)
            except:
                print("Error with song: " + filename)
                os.remove(initial_path + filename)
remove_unused_instruments(filtered_path, guitar_bass_path)

# %%
def make_sure_everything_is_okey(path):
    for _, _, filenames in os.walk(path):
        for filename in filenames:
            try:
                mid = mido.MidiFile(path + filename)
                print("Loaded: " + filename)
                if len(mid.tracks) != 2:
                    print("Deleted: " + filename)
                    os.remove((path + filename))
            except:
                print("Error with song: " + filename)
                os.remove((path + filename))
# make_sure_everything_is_okey(guitar_bass_path)

# %%
def check_songs_velocities(path):
    has_120_vels = 0
    doesnt = 0
    i = 0
    for _, _, filenames in os.walk(path):
        for filename in filenames:
            has_120 = True
            if i % 100 == 0:
                print(has_120_vels, doesnt)
            i = i + 1
            try:
                mid = mido.MidiFile(path + filename)
                for track in mid.tracks:
                    for msg in track:
                        if msg.type == "note_on":
                            if msg.velocity != 120:
                                has_120 = False
                if has_120:
                    has_120_vels = has_120_vels + 1
                else:
                    doesnt = doesnt + 1
            except:
                print("Error with song: " + filename)
                os.remove((path + filename))
                
    return has_120_vels, doesnt
has_120_vels, doesnt = check_songs_velocities(guitar_bass_path) #124 25376

# %%
def get_lengths_and_notes(path):
    min_notes = []
    max_notes = []
    lens = []
    i = 0
    for _, _, filenames in os.walk(path):
        for filename in filenames:
            if i % 1000 == 0:
                print(i, 25376)
            i = i + 1
            try:
                mid = mido.MidiFile(path + filename)
                for track in mid.tracks:
                    min_note = 999
                    max_note = -1
                    for msg in track:
                        if msg.type == "note_on":
                            if msg.note < min_note:
                                min_note = msg.note
                            if msg.note > max_note:
                                max_note = msg.note
                    min_notes.append(min_note)
                    max_notes.append(max_note)
                    lens.append(len(track))
            except:
                print("Error with song: " + filename)
                os.remove((path + filename))
    return min_notes, max_notes, lens
# min_notes, max_notes, lens = get_lengths_and_notes(guitar_bass_path)
# print(min_notes, max_notes, lens)

# %%
lens.sort()
rounded_lens = list(map(lambda x: round(x, -2), lens))
count = Counter(rounded_lens)
df = pandas.DataFrame.from_dict(count, orient='index')
df.plot(kind='bar', title='Lens', figsize=(40,5))
# max len 5000

# %%
min_notes.sort()
rounded = list(map(lambda x: round(x, -1), min_notes))
count = Counter(min_notes)
df = pandas.DataFrame.from_dict(count, orient='index')
df.plot(kind='bar', title='Min notes', figsize=(40,5))

# %%
max_notes.sort()
rounded = list(map(lambda x: round(x, -1), max_notes))
count = Counter(max_notes)
df = pandas.DataFrame.from_dict(count, orient='index')
df.plot(kind='bar', title='Min notes', figsize=(40,5))

# %%
def multifilter(initial_path, final_path):
    i = 0
    for _, _, filenames in os.walk(initial_path):
        for filename in filenames:
            if i % 1000 == 0:
                print(i, 25376)
            i = i + 1
            try:
                mid = mido.MidiFile(initial_path + filename)
                min_note = 999
                max_note = -1
                for track in mid.tracks:
                    for msg in track:
                        if msg.type == "note_on":
                            if msg.note < min_note:
                                min_note = msg.note
                            if msg.note > max_note:
                                max_note = msg.note
                if min_note > 20 and min_note != 999 and max_note < 90 and max_note != -1 and len(mid.tracks[0]) < 4000 and len(mid.tracks[1]) < 4000:
                    os.rename(initial_path + filename, final_path + filename)
                else:
                    os.remove(initial_path + filename)
            except Exception as e:
                print("Error with song: " + filename)
                print(e)
                os.remove(initial_path + filename)
                
initial_path = "/Users/edlgg/repos/dissertation/midis/guitar_bass_midis/"
final_path = "/Users/edlgg/repos/dissertation/midis/guitar_bass_filtered/"
multifilter(initial_path, final_path)
# Out:
# 0 25376
# 1000 25376
# 2000 25376
# 3000 25376
# 4000 25376
# 5000 25376

# %%
#get_track_ins
def clean_songs(initial_path, final_path):
    i = 0
    for _, _, filenames in os.walk(initial_path):
        for filename in filenames:
            try:
                if i % 100 == 0:
                    print(i)
                i = i + 1
                old_mid = mido.MidiFile(initial_path + filename)

                track_one_type = get_track_instrument_type(old_mid.tracks[0])
                guitar = None
                bass = None
                if track_one_type == "Guitar":
                    guitar = old_mid.tracks[0]
                    bass = old_mid.tracks[1]
                else:
                    guitar = old_mid.tracks[1]
                    bass = old_mid.tracks[0]

                new_guitar = mido.MidiTrack()
                new_guitar.append(mido.Message('program_change', program=28, time=0))
                for msg in guitar:
                    if msg.type == "note_on":
                        new_guitar.append(msg)

                new_bass = mido.MidiTrack()
                new_bass.append(mido.Message('program_change', program=35, time=0))
                for msg in bass:
                    if msg.type == "note_on":
                        new_bass.append(msg)


                new_mid = mido.MidiFile()
                new_mid.tracks.append(new_guitar)
                new_mid.tracks.append(new_bass)
                new_mid.save(final_path + filename)
                os.remove(initial_path + filename)
            except Exception as e:
                print(filename, e)
            
initial_path = "/Users/edlgg/repos/dissertation/midis/guitar_bass_filtered/"
final_path = "/Users/edlgg/repos/dissertation/midis/clean_songs/"
clean_songs(initial_path, final_path)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# .DS_Store MThd not found. Probably not a MIDI file
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500

# %%
def get_instrument_track(mid, desired_type):
    desired_track = mido.MidiTrack()
    for track in mid.tracks:
        track_type = get_track_instrument_type(track)
        if track_type == desired_type and len(track) > len(desired_track):
            desired_track = track
    return desired_track

# %%
def validate_notes_and_vels(mid):
    min_ = 999
    max_ = -1
    has_0_vel = False
    has_note_off = False
    has_control_change = False
    for track in mid.tracks:
        for msg in track:
            if msg.type == "note_on":
                if msg.note < min_:
                    min_ = msg.note
                if msg.note > max_:
                    max_ = msg.note
                if msg.velocity == 0:
                    has_0_vel = True
            if msg.type == "note_off":
                has_note_off = True
            if msg.type == "control_change":
                has_control_change = True
    if min_ == 999 or min_ < 20 or max_ == -1 or max_ > 90 or (has_0_vel and has_note_off) or (not has_0_vel and not has_note_off):
        return False, has_control_change, has_0_vel, has_note_off
    return True, has_control_change, has_0_vel, has_note_off

# %%
def master_filter():
    initial_path = "/Users/edlgg/repos/dissertation/midis/all_midis/"
    final_path = "/Users/edlgg/repos/dissertation/midis/v3/" 
    allowed_ticks = [120, 384, 480, 192]
    i = 0
    for _, _, filenames in os.walk(initial_path):
        for filename in filenames:
            try:
                if i % 1000 == 0:
                    print(i, str(117102))
                i = i + 1
                old_mid = mido.MidiFile(initial_path + filename)
                ticks_per_beat = old_mid.ticks_per_beat
                is_valid, has_control_change, has_0_vel, has_note_off = validate_notes_and_vels(old_mid)
                if ticks_per_beat in allowed_ticks and is_valid:
                    guitar = get_instrument_track(old_mid, "Guitar")
                    bass = get_instrument_track(old_mid, "Bass")
                    
                    if len(guitar) > 500 and len(bass) > 500:
                        new_guitar = mido.MidiTrack()
                        new_guitar.append(mido.Message('program_change', program=26, time=0))
                        for msg in guitar:
                            if msg.type == "note_on":
                                new_guitar.append(msg)

                        new_bass = mido.MidiTrack()
                        new_bass.append(mido.Message('program_change', program=34, time=0))
                        for msg in bass:
                            if msg.type == "note_on":
                                new_bass.append(msg)

                        new_mid = mido.MidiFile()
                        new_mid.ticks_per_beat = ticks_per_beat
                        new_mid.tracks.append(new_guitar)
                        new_mid.tracks.append(new_bass)
                        
                        path = final_path
                        if has_control_change:
                            path = path + "control_change/" 
                        else:
                            path = path +  "no_control_change/"
                        if has_0_vel:
                            path = path + "0_vel/"
                        else:
                            path = path + "note_off/"
                        path = path + str(ticks_per_beat) + "/" + filename
                        new_mid.save(path)
                    os.remove(initial_path + filename)
            except Exception as e:
                print("Error with file: ", filename)
                print(" Error: " , e)
                os.remove(initial_path + filename)
master_filter()
# Out:
# 0 117102
# Error with file:  warcraft.mid
#  Error:
# Error with file:  Spear K - Astromon.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  B5th_3g.mid
#  Error:  Could not decode key with 10 sharps and mode 0
# Error with file:  victory-4.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  inlambs.mid
#  Error:  Could not decode key with 3 flats and mode 21
# Error with file:  IWill2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  LWmid.mid
#  Error:
# Error with file:  kainoe.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Misja Helsloot - First Second (Ralphie B Remix).mid
#  Error:  list index out of range
# Error with file:  Lady Gaga - Hair.mid
#  Error:  data byte must be in range 0..127
# Error with file:  because_u_love_me.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Prelude op32 n5 .mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  SailorScoutsTransformationAndAttackTheme4.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  barbie_girl.mid
#  Error:
# Error with file:  Animaniacs.mid
#  Error:  Could not decode key with 4 flats and mode 255
# Error with file:  Laidback_Luke_Sebastian_Ingrosso_Axwell_Steve_Angello_-_Leave_The_World_Behind__John_20110625163550.mid
#  Error:  list index out of range
# Error with file:  Sindre Eide - Only When I Sleep.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  a-rock.mid
#  Error:
# Error with file:  beet53.mid
#  Error:  Could not decode key with 10 sharps and mode 0
# Error with file:  Love-Is-In-The-Air-4.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Spaghetti.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Kai Tracid - Too Many Times.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Limbeck.mid
#  Error:
# 1000 117102
# Error with file:  hop11.mid
#  Error:  data byte must be in range 0..127
# Error with file:  munster.mid
#  Error:
# Error with file:  Avicii ft. David Guetta - Sunshine.mid
#  Error:  list index out of range
# Error with file:  nguoi_dien_yeu_trang_(cn).mid
#  Error:  data byte must be in range 0..127
# Error with file:  Fantasia-Nr-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  sevdaliy.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Ghostbusters2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  conga03.mid
#  Error:  data byte must be in range 0..127
# Error with file:  angelaerosmith.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Journey - Lights.mid
#  Error:  data byte must be in range 0..127
# Error with file:  the_happy_wanderer_fs.mid
#  Error:
# Error with file:  coldplay-amsterdam.mid
#  Error:  data byte must be in range 0..127
# Error with file:  freeze88KOH.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Web - Loving Times (Signum Remix).mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  LED ZEPPELIN.Ramble on.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/LED ZEPPELIN.Ramble on.mid'
# Error with file:  blackeyed_sailor_hd.mid
#  Error:  data byte must be in range 0..127
# Error with file:  ff2prlge.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  fc2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  hair.mid
#  Error:  data byte must be in range 0..127
# Error with file:  game02.mid
#  Error:  data byte must be in range 0..127
# Error with file:  ganpar.mid
#  Error:
# Error with file:  champ.mid
#  Error:
# Error with file:  sale.mid
#  Error:  data byte must be in range 0..127
# Error with file:  newyear2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  red_hot_chili_peppers-pea.mid
#  Error:  MThd not found. Probably not a MIDI file
# 2000 117102
# Error with file:  There's-A-Place.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  superman04.mid
#  Error:  data byte must be in range 0..127
# Error with file:  war1.mid
#  Error:
# Error with file:  bm98.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  AlessoSebastianIngrosso_-_Calling__djrenco_20130225212910.mid
#  Error:  list index out of range
# Error with file:  addams.mid
#  Error:  data byte must be in range 0..127
# Error with file:  san_ga_chi_co_mot_nguoi_(a).mid
#  Error:  data byte must be in range 0..127
# Error with file:  Disney_Themes_-_When_You_Wish_Upon_A_Star.mid
#  Error:  data byte must be in range 0..127
# Error with file:  preludgm.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Nirvana_-_Radio_Friendly_Unit_Shifter.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Maru_-_Insane_Youth__John_20100419152019.mid
#  Error:  list index out of range
# Error with file:  200103.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  EMIWontHoldYouBackNow.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  Riva_-_RunAway__Zoik_20130128215905.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  The-Snow-Goose-1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  thanh_pho_mua_bay.mid
#  Error:  data byte must be in range 0..127
# Error with file:  UniFFsong.mid
#  Error:  data byte must be in range 0..127
# Error with file:  S.BALLET.I'll  fly for you.mid
#  Error:  data byte must be in range 0..127
# Error with file:  mortal_kombat.mid
#  Error:
# 3000 117102
# Error with file:  Therainleavesascar.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Leader_Of_Men_Acoustic_Version.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Dirty South, Those Usual Suspects - Walking Alone.mid
#  Error:  list index out of range
# Error with file:  Milk__Sugar_feat._Miriam_Makeba_-_Hi-a_Ma_(Pata_Pata)_(Yves_Murasca_Nu-Afrocan_Dub_Remix)_(Break)__John_20110820094705.mid
#  Error:  list index out of range
# Error with file:  Oh-Starry-Night.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  dontmiss.mid
#  Error:  data byte must be in range 0..127
# Error with file:  itmight.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  Parallel_Universe.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  passage_to_pandemonium.mid
#  Error:  data byte must be in range 0..127
# Error with file:  smsdidi.mid
#  Error:  data byte must be in range 0..127
# Error with file:  NWomNCry.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Axwell - Heart is King.mid
#  Error:  list index out of range
# Error with file:  tryme.mid
#  Error:
# Error with file:  countryroad.mid
#  Error:  data byte must be in range 0..127
# Error with file:  The Organ Donors - Locked Tight Trance Remix.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  summer_o.mid
#  Error:
# Error with file:  sclife.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  jsb0244b.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Blurryeyes.mid
#  Error:  data byte must be in range 0..127
# 4000 117102
# Error with file:  funnyguy.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Rusch & Murray - Promise.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  thrill2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Asifinadream.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Nirvana - Been A Son.mid
#  Error:  running status without last_status
# Error with file:  geri_halliwell-mi_chico_latino.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Andy_Moor_vs._Orkidea_-_Yearzero__devinjv_20070128191153.mid
#  Error:  list index out of range
# Error with file:  Deana_Carter_-_Strawberry_Wine.mid
#  Error:
# Error with file:  tieng_quoc_dem_trang.mid
#  Error:  data byte must be in range 0..127
# Error with file:  flute05.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Treasure.mid
#  Error:
# Error with file:  what_a_wonderful_world2.mid
#  Error:
# Error with file:  Atalanta Fugiens No.21.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Like-Ice-In-The-Sunshine-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Flashheadz - Wizards Of The Sonic 2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Backst.mid
#  Error:
# Error with file:  Dancecube - Cold Trap.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  inthmood2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  La-Dolce-Vita-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  songwhiteshade.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Tom_Hangs_ft_Shermanology_-_Blessed_(Avicii_Edit)__djrenco_20110425170813.mid
#  Error:  list index out of range
# 5000 117102
# Error with file:  smooth1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Sylver - Living My Life.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  linkin_park-minutes_to_midnight.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  rosanna1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  48.mid
#  Error:
# Error with file:  laser_inc__det_var_en_gng_fgel__djrenco.mid
#  Error:  list index out of range
# Error with file:  game03.mid
#  Error:  data byte must be in range 0..127
# Error with file:  a_ha-the_way_we_talk.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Die-Bouzouki-Klang-Durch-Die-Sommernacht.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Deep_Kick.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  bai_ca_dat_phuong_nam_(a).mid
#  Error:  data byte must be in range 0..127
# Error with file:  horde2.mid
#  Error:
# Error with file:  bphym160.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  12strag.mid
#  Error:  Could not decode key with 2 flats and mode 39
# Error with file:  SomethingInTheWaySheMoves.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  frozen03.mid
#  Error:
# Error with file:  J.DENVER.Rhymes and reason.mid
#  Error:  data byte must be in range 0..127
# Error with file:  come_to_me.mid
#  Error:
# Error with file:  Leave-That-Thing-Alone.mid
#  Error:  data byte must be in range 0..127
# Error with file:  BKgruntilda3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Karamba-Karacho-Ein-Whisky-2.mid
#  Error:  data byte must be in range 0..127
# 6000 117102
# Error with file:  All-Cried-Out.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Vring.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Paths.mid
#  Error:
# Error with file:  Ghostbusters3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  wrongbnd.mid
#  Error:  Could not decode key with 5 flats and mode 255
# Error with file:  hcoin.mid
#  Error:  data byte must be in range 0..127
# Error with file:  em_yeu_ai.mid
#  Error:  data byte must be in range 0..127
# Error with file:  negra.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Surreal - U Take My Breath Away.mid
#  Error:  data byte must be in range 0..127
# Error with file:  dustman.mid
#  Error:  data byte must be in range 0..127
# Error with file:  m_loc.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Goodbyelove.mid
#  Error:
# Error with file:  Pokemon - Littleroot Town.mid
#  Error:  data byte must be in range 0..127
# Error with file:  avrai.mid
#  Error:  data byte must be in range 0..127
# Error with file:  in_your_eyes.mid
#  Error:  data byte must be in range 0..127
# Error with file:  opus6.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  norwegian_wood2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  canon3.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  My Digital Enemy, Carl Hanaghan - Atlas (Vision Factory Remix).mid
#  Error:  list index out of range
# Error with file:  subdivs.mid
#  Error:  data byte must be in range 0..127
# Error with file:  ly_chim_quyen_(cn).mid
#  Error:  data byte must be in range 0..127
# Error with file:  Jet_Pilot.mid
#  Error:  data byte must be in range 0..127
# Error with file:  u2stay.mid
#  Error:
# Error with file:  beet52.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Mahler_Gustav_-_Symphony_#2_(Tenor).mid
#  Error:  data byte must be in range 0..127
# Error with file:  Balbasbow2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  shoop3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  somebody2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  PinkSpider.mid
#  Error:  data byte must be in range 0..127
# Error with file:  victoria.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Tiesto_-_OlympicFlameversion2__SamCera_20130127090153.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  DRUMDATA_DnbDemo.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Michael Woods - Airborne.mid
#  Error:  list index out of range
# Error with file:  santana-guajira.mid
#  Error:  data byte must be in range 0..127
# Error with file:  tieng_mua_roi.mid
#  Error:  data byte must be in range 0..127
# 7000 117102
# Error with file:  spider_man.mid
#  Error:  data byte must be in range 0..127
# Error with file:  queer03.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  earthbnd.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Sam_Sparro_-_Black__Gold__John_20081221195757.mid
#  Error:  list index out of range
# Error with file:  Big-Spender.mid
#  Error:  data byte must be in range 0..127
# Error with file:  National_Anthems_-_Mongolia.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Pernambuco_Brasileirinho.mid
#  Error:  wrong number of bytes for stop message
# Error with file:  maiden_voyage-HHancock_bg.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Clokx - Feelings.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Dirty_Money_-_Hello_Good_Morning_(Erick_Morillo__Eddie_Thoneick_Bootleg)__djrenco_20110506102831.mid
#  Error:  list index out of range
# Error with file:  Promenade-4-Ballet-Of-Chickens.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Greasmx.mid
#  Error:  data byte must be in range 0..127
# Error with file:  sf2dhals.mid
#  Error:  data byte must be in range 0..127
# Error with file:  penpen.mid
#  Error:  data byte must be in range 0..127
# Error with file:  bumble_b.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Chuckie - Together.mid
#  Error:  list index out of range
# Error with file:  ranma1.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  Alesso_-_Years__djrenco_20120302183925.mid
#  Error:  list index out of range
# Error with file:  John_Dahlback_-_Pyramid_(Dirty_South_Remix)__John_20081211001302.mid
#  Error:  list index out of range
# Error with file:  iwillsurvive1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  a_bow.mid
#  Error:
# Error with file:  imsorry03.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  ff2endx.mid
#  Error:  data byte must be in range 0..127
# Error with file:  gloria_estefan-any_thing_for_you.mid
#  Error:  MThd not found. Probably not a MIDI file
# 8000 117102
# Error with file:  Dubfire_-_Roadkill_(EDX_Belo_Horizonte_At_Night_Mix)__djrenco_20110509115749.mid
#  Error:  list index out of range
# Error with file:  Kumata - Discovery.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Somewhere2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Only-You-3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  semperfi.mid
#  Error:
# Error with file:  illbsee.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  ffairship.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  pa_cand.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/192/pa_cand.mid'
# Error with file:  virgin2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  MILES.Children.mid
#  Error:  data byte must be in range 0..127
# Error with file:  All-You-Need-Is-Love-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  forest2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Please_Please_Me.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  rem-night_swimming.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  terror-org_mh3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  hero03.mid
#  Error:
# Error with file:  chamber.mid
#  Error:
# Error with file:  Chariots-Of-Fire-3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  David_Guetta_vs_Afrojack_-_Louder_Than_Words__djrenco_20110506102723.mid
#  Error:  list index out of range
# Error with file:  Heirate_Mich.mid
#  Error:  MThd not found. Probably not a MIDI file
# 9000 117102
# Error with file:  celebrate_jesus2.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  DParkKOH.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  47sda.mid
#  Error:
# Error with file:  ta_tirando_onda2.mid
#  Error:
# Error with file:  liberty3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Misja_Helsloot_-_First_Second_(Ralphie_B_Remix)__John_20080616190450.mid
#  Error:  list index out of range
# Error with file:  Kingdom Hearts II: Final Mix - The Other Promise.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  mds2haoh.mid
#  Error:  data byte must be in range 0..127
# Error with file:  cherokee2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  tenuisti.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  bulletme.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Dont_cry_for_me.mid
#  Error:
# Error with file:  Piazzola_Verano_Porteno2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  border.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  game01.mid
#  Error:  data byte must be in range 0..127
# Error with file:  stair_h2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  My_Digital_Enemy_Carl_Hanaghan_-_Atlas_(Vision_Factory_Remix)__John_20090419004828.mid
#  Error:  list index out of range
# Error with file:  clar4.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  war2.mid
#  Error:
# Error with file:  Temper_Traps_-_Sweet_Disposition_(Axwell__Dirty_South_Remix)__DJRenco_20091029121912.mid
#  Error:  list index out of range
# Error with file:  mrs_rob1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  miami_vice.mid
#  Error:
# Error with file:  threemice.mid
#  Error:
# Error with file:  DavidGuettaftUsher_-_WithoutYou__djrenco_20130202051555.mid
#  Error:  list index out of range
# Error with file:  red_hot_chili_peppers-under_the_bridge.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  generatedharmony.mid
#  Error:  Could not decode key with 8 sharps and mode 0
# Error with file:  Final Fantasy VII-Crisis Core - A Flower Blooming in the Slums.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Led Zeppelin - Custard Pie.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Nirvana_-_Polly_(New_Wave).mid
#  Error:  running status without last_status
# Error with file:  Fortuna.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Nikita2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Thomas_Gold_-_Marsch_Marsch__John_20110406114747.mid
#  Error:  list index out of range
# Error with file:  zhyrule.mid
#  Error:  MThd not found. Probably not a MIDI file
# 10000 117102
# Error with file:  lou_bega_-_mambo_no_51.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  c04027.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  xin_dung_roi_xa.mid
#  Error:  data byte must be in range 0..127
# Error with file:  comingbacktolife.mid
#  Error:  data byte must be in range 0..127
# Error with file:  PerfectNanny.mid
#  Error:
# Error with file:  8th-Symphony-Part-1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  John Dahlback - Pyramid (Dirty South Remix).mid
#  Error:  list index out of range
# Error with file:  My_Friend_Sam_-_My_Pleasure_(Raul_Rincon_Remix)__John_20081221195829.mid
#  Error:  list index out of range
# Error with file:  The-Snow-Goose-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  around5.mid
#  Error:  running status without last_status
# Error with file:  blues7.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  KOH - Clone.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  D.FOGELBERG.Leader of the band.mid
#  Error:  Could not decode key with 4 flats and mode 255
# Error with file:  mking.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  T0.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Tiesto & Mark Knight ft. Dino - Beautiful World.mid
#  Error:  list index out of range
# Error with file:  peaceful05.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  havetime.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  ridelike1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  walking3.mid
#  Error:
# Error with file:  forrest5.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  actesmanques.mid
#  Error:  data byte must be in range 0..127
# 11000 117102
# Error with file:  horse03.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  sera03.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  hoai_mong.mid
#  Error:  data byte must be in range 0..127
# Error with file:  let_it_ride.mid
#  Error:
# Error with file:  Godsmack_-_Moon_Baby.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/Godsmack_-_Moon_Baby.mid'
# Error with file:  sea-sky.mid
#  Error:
# Error with file:  KOH - Digital Park.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Du-Hast-Geburtstag.mid
#  Error:  data byte must be in range 0..127
# Error with file:  evanescence__my_immortal_john.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Ssnnysde.mid
#  Error:  data byte must be in range 0..127
# Error with file:  wonder_wall.mid
#  Error:
# Error with file:  LimboRock.mid
#  Error:  data byte must be in range 0..127
# Error with file:  guilesf.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Snocap_-_What_I_desire__snocap_20081125231833.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Sifting.mid
#  Error:
# Error with file:  caribbean_blue.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  LVBeethoven_FurElise.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  imhawaii(1).mid
#  Error:  MThd not found. Probably not a MIDI file
# 12000 117102
# Error with file:  MegaManX-Firststage.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Kufsteiner-Lied.mid
#  Error:  data byte must be in range 0..127
# Error with file:  sober3.mid
#  Error:
# Error with file:  jjjhs.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  rocky05.mid
#  Error:
# Error with file:  The-Trial.mid
#  Error:
# Error with file:  fade.mid
#  Error:  running status without last_status
# Error with file:  tiento.mid
#  Error:  data byte must be in range 0..127
# Error with file:  lacopa.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  heysong.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Klavier.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  asend.mid
#  Error:
# Error with file:  Golden Axe II - The Castle.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  apache08.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Gabriel & Dresden - Tracking Treasure Down.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Nirvana_-_Hairspray_Queen.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Manor.mid
#  Error:
# Error with file:  gloria_estefan-breaking_up_is_hard_to_do.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  allhail3.mid
#  Error:
# Error with file:  k.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  clar5.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Bring_Me_To_Life_2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Points_Of_Authority.mid
#  Error:  data byte must be in range 0..127
# Error with file:  track15.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  The-Only-Way-Is-Up-1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Nursery.mid
#  Error:
# Error with file:  tainted.mid
#  Error:  MThd not found. Probably not a MIDI file
# 13000 117102
# Error with file:  Nirvana - Tourette's.mid
#  Error:  data byte must be in range 0..127
# Error with file:  red_hot_chili_peppers-parallel_universe.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  onethat.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  lvl14.mid
#  Error:  data byte must be in range 0..127
# Error with file:  zion.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  Dj Disciple - Work It Out (Klaas Remix).mid
#  Error:  list index out of range
# Error with file:  dannyboy3.mid
#  Error:  attribute must be in range 0..99
# Error with file:  babe3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  manger5.mid
#  Error:  data byte must be in range 0..127
# Error with file:  oneheadlight.mid
#  Error:  Could not decode key with 5 flats and mode 255
# Error with file:  chim_sao_tro_ve_(cn).mid
#  Error:  data byte must be in range 0..127
# Error with file:  belleetc.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  milldau.mid
#  Error:  Could not decode key with 0 flats and mode 184
# Error with file:  Double Dragon II The Revenge - Undersea Base.mid
#  Error:  MThd not found. Probably not a MIDI file
# 14000 117102
# Error with file:  Andy Bagguley & Dj Genix presesents Oracle - The One.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  burana2.mid
#  Error:  Could not decode key with 1 flats and mode 2
# Error with file:  DNBThemeofGenomGrifondeath13.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  megido3.mid
#  Error:
# Error with file:  mai_yeu_em.mid
#  Error:  data byte must be in range 0..127
# Error with file:  I-Can-Help.mid
#  Error:  data byte must be in range 0..127
# Error with file:  cantaloop2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  KEYS.A woman's sworth k.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Abarrach.mid
#  Error:
# Error with file:  kepfaith.mid
#  Error:
# Error with file:  Macarena3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  ffcave.mid
#  Error:  Could not decode key with 4 flats and mode 255
# Error with file:  muse-supermassive_black_hole.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Ik-Meen-'t-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Otherside.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  TJblue_install.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  rainydayman2.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Airwave_aka_Lolo_-_Travel_The_World_In_10_Minutes__jnlc_wu_20110311101634.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  erailb4.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  ICE CUBE.Can i get a.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Buxethude Buxwv138 Prelude.mid
#  Error:  list index out of range
# Error with file:  rabbithill.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  AQUA.Dr Jones K.mid
#  Error:  data byte must be in range 0..127
# Error with file:  purelise.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  10000yr.mid
#  Error:  MThd not found. Probably not a MIDI file
# 15000 117102
# Error with file:  Flashheadz_-_wizards_of_the_sonic2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  hulahand.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  twilight03.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  trouble_by_travis.mid
#  Error:
# Error with file:  Two_Of_Us.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Sia - Breathe Me (Mylo Mix).mid
#  Error:  list index out of range
# Error with file:  needyou.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  18auntdinah.mid
#  Error:  Could not decode key with 2 flats and mode 44
# Error with file:  My Friend Sam - My Pleasure (Raul Rincon Remix).mid
#  Error:  list index out of range
# Error with file:  willyous.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  crazy-5.mid
#  Error:  Could not decode key with 1 flats and mode 197
# Error with file:  Cafe-Del-Mar.mid
#  Error:  data byte must be in range 0..127
# Error with file:  keepaway.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/keepaway.mid'
# Error with file:  knowyouloveyou.mid
#  Error:  data byte must be in range 0..127
# Error with file:  monkey04.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  everytime03.mid
#  Error:
# Error with file:  newstuff.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Sunbeam - Outside World.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Deine-Fluegel-Fangen-Feuer-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  1223.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  prtywoman.mid
#  Error:  data byte must be in range 0..127
# 16000 117102
# Error with file:  MM-the love song.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  moonhealingactivation.mid
#  Error:  Could not decode key with 7 flats and mode 255
# Error with file:  jupiter.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  EMAllIWantToDoIsMakeLoveToYou.mid
#  Error:
# Error with file:  EpisodeEnder.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  METALLICA.The unforgiven II K.mid
#  Error:  data byte must be in range 0..127
# Error with file:  trulymadly.mid
#  Error:
# Error with file:  Beastie_Boys_-_Girls.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Ayumi_Hamasaki_Love_Destiny.mid
#  Error:  data byte must be in range 0..127
# Error with file:  thrplace.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Scars - Pneumatic Poem.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  qfg3savannah.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Francois Dennig - Tight Gloss.mid
#  Error:  list index out of range
# Error with file:  902103.mid
#  Error:  data byte must be in range 0..127
# Error with file:  qfg2aziza.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Get-Back-3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  rose08.mid
#  Error:  data byte must be in range 0..127
# Error with file:  ThatsWhatFriendsAreFor.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Nirvana_-_Polly.mid
#  Error:  data byte must be in range 0..127
# Error with file:  starbar.mid
#  Error:
# Error with file:  Tavern.mid
#  Error:
# Error with file:  Nelly_-_Country_Grammar.mid
#  Error:  data byte must be in range 0..127
# Error with file:  tetris.mid
#  Error:  data byte must be in range 0..127
# Error with file:  waikiki.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Jackson_5_-_I_Want_You_Back.mid
#  Error:
# Error with file:  oneman.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  powerofdreams1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  young2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  bpsong.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  mappari.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  clar1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  game04.mid
#  Error:  data byte must be in range 0..127
# 17000 117102
# Error with file:  tinh_yeu_con_dau.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Atalanta Fugiens No.32.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Promenade-2-The-Old-Castle.mid
#  Error:  Could not decode key with 4 flats and mode 255
# Error with file:  iswear06.mid
#  Error:  data byte must be in range 0..127
# Error with file:  olympics.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Scott Brown ft. Cat Knight - All About You.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Hello-Again-1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Fada.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  monty.mid
#  Error:  data byte must be in range 0..127
# Error with file:  .DS_Store
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  summerslam.mid
#  Error:
# Error with file:  PepperEyes.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Highway_Song.mid
#  Error:  data byte must be in range 0..127
# Error with file:  80-04-duke2.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/80-04-duke2.mid'
# Error with file:  miamivic1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  8th-Symphony-Part-4.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Think_of_Me.mid
#  Error:  Could not decode key with 2 flats and mode 161
# Error with file:  SmellsLikeTeenSpirit.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  duyen_dang_ao_hoa.mid
#  Error:  data byte must be in range 0..127
# Error with file:  bossbattle.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  qfg4open.mid
#  Error:  data byte must be in range 0..127
# Error with file:  tpfreefa.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/tpfreefa.mid'
# 18000 117102
# Error with file:  EarthBound - Summers.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  NRG_-_He_Never_Lost_His_Hardcore__John_20080623134453.mid
#  Error:  list index out of range
# Error with file:  dallas2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  lover2.mid
#  Error:
# Error with file:  Pryda_-_Muranyi__John_20081211001107.mid
#  Error:  list index out of range
# Error with file:  chriscandido.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Carl_Louis__Martin_Danielle_-_Little_Bit__djrenco_20110521113115.mid
#  Error:  list index out of range
# Error with file:  Links_234.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/Links_234.mid'
# Error with file:  hon_vong_phu_(cn).mid
#  Error:  data byte must be in range 0..127
# Error with file:  BLACK MACHINE.Jazz machine.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Summer3.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  fodreams.mid
#  Error:  Could not decode key with 4 flats and mode 2
# Error with file:  stelmosfire2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Tetris - Music A.mid
#  Error:  data byte must be in range 0..127
# Error with file:  intheend3.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  doi_chan_thien_than.mid
#  Error:  data byte must be in range 0..127
# Error with file:  congragm.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Hybrid - Celebrity Science.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  eranapeace.mid
#  Error:
# Error with file:  smusic22.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  Nirvana - Radio Friendly Unit Shifter.mid
#  Error:  data byte must be in range 0..127
# Error with file:  ijustcalledtosayiloveyou2.mid
#  Error:
# Error with file:  ghostrid1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  march4.mid
#  Error:  running status without last_status
# Error with file:  MM-tainted love.mid
#  Error:  MThd not found. Probably not a MIDI file
# 19000 117102
# Error with file:  flut_beethoven.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  ai_ve_song_tuong.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Etude-Trancendentale-Feux-Follets.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  uninvited3.mid
#  Error:
# Error with file:  DYLAN.Blowing in the wind K.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/DYLAN.Blowing in the wind K.mid'
# Error with file:  ladyinre1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  system_of_a_down-deer_dance.mid
#  Error:  data byte must be in range 0..127
# Error with file:  sumnite.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  triumphalmarch.mid
#  Error:  Could not decode key with 4 flats and mode 255
# Error with file:  EDX_-_Embrace__djrenco_20110417202320.mid
#  Error:  list index out of range
# Error with file:  Tom_Novy_-_Runaway__John_20080701194909.mid
#  Error:  list index out of range
# Error with file:  Alex_Megane_vs_Marc_van_Damme_-_Technodisco_(Rob_Mayth_Remix)__Djnard_20060623141527.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Donna-Lee.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Zoom.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  taps07.mid
#  Error:  data byte must be in range 0..127
# Error with file:  K.C.SUNSHINE BAND.That's the way K.mid
#  Error:  data byte must be in range 0..127
# Error with file:  steel2.mid
#  Error:
# Error with file:  canon06.mid
#  Error:  data byte must be in range 0..127
# Error with file:  eva-02.mid
#  Error:  data byte must be in range 0..127
# Error with file:  santacom2.mid
#  Error:
# Error with file:  yahel_avalanche__senses_remix__saphrano.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  game05.mid
#  Error:  data byte must be in range 0..127
# Error with file:  hotelcal1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Eien_no_Melody.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  track04.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Adv.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Dj_Disciple_-_Work_It_Out_(Klaas_Remix)__John_20090303180754.mid
#  Error:  list index out of range
# Error with file:  Mahler_Gustav_-_Symphony_#2_(Tenor2).mid
#  Error:  data byte must be in range 0..127
# 20000 117102
# Error with file:  every_little_thing.mid
#  Error:  data byte must be in range 0..127
# Error with file:  animx2.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  rule.mid
#  Error:  data byte must be in range 0..127
# Error with file:  andyl15.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  dntwana.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Lessons-In-Love-3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  lvl11.mid
#  Error:  data byte must be in range 0..127
# Error with file:  greatfaith.mid
#  Error:
# Error with file:  Nirvana_Been_A_Son.mid
#  Error:  running status without last_status
# Error with file:  LinkinPark_Faint1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Thunder.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Dreadlock-Holiday-3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  walkingonsun.mid
#  Error:  data byte must be in range 0..127
# Error with file:  qfg3inn.mid
#  Error:  data byte must be in range 0..127
# Error with file:  bittersweet3.mid
#  Error:
# Error with file:  black_lace.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/480/black_lace.mid'
# Error with file:  dinoboss.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Tarzan.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  tequila05.mid
#  Error:  data byte must be in range 0..127
# Error with file:  thacrossroads.mid
#  Error:  data byte must be in range 0..127
# Error with file:  MM-Great big white world1.mid
#  Error:  MThd not found. Probably not a MIDI file
# 21000 117102
# Error with file:  helen-re.mid
#  Error:
# Error with file:  Nirvana_-_Frances_Farmer_Will_Have_Her_Revenge_On_Seattle.mid
#  Error:  running status without last_status
# Error with file:  Dan-J_-_A_Lonely_World_(Orginal_Mix)__TerraNation_20101218005132.mid
#  Error:  data byte must be in range 0..127
# Error with file:  binh_duong_tuoi_tho_toi.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Unforgiven2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  walking_on_the_sun-smash_mouth.mid
#  Error:
# Error with file:  tam_su_cua_toi_(cn).mid
#  Error:  data byte must be in range 0..127
# Error with file:  Alex Megane vs Marc van Damme - Technodisco (Rob Mayth Remix).mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  MuskratRamble.mid
#  Error:  Could not decode key with 8 sharps and mode 1
# Error with file:  JamesBlunt_-_SuperstarDaddysGrooveRemix__SamCera_20120416202332.mid
#  Error:  list index out of range
# Error with file:  dontgobr1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  law.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  beet54.mid
#  Error:  running status without last_status
# Error with file:  Rammstein - Seemann_v1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  con_duong_mang_ten_em_(cn).mid
#  Error:  data byte must be in range 0..127
# Error with file:  nickelback-leader_of_men_acoustic_version.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Nirvana_-_Dive.mid
#  Error:  data byte must be in range 0..127
# Error with file:  X-Files.mid
#  Error:
# Error with file:  music-40.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Led-StairwayToHaven.mid
#  Error:
# Error with file:  chestnuts2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  mayfair.mid
#  Error:  data byte must be in range 0..127
# Error with file:  st_elmo.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Avicii_-_Levels__djrenco_20110506102201.mid
#  Error:  list index out of range
# 22000 117102
# Error with file:  juanga-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  hay_den_voi_toi.mid
#  Error:  data byte must be in range 0..127
# Error with file:  japblue.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  system_of_a_down-atwa.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/480/system_of_a_down-atwa.mid'
# Error with file:  wstreet.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  FreeFalling.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/FreeFalling.mid'
# Error with file:  the_girl_from_yesterday.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Gotham.mid
#  Error:  data byte must be in range 0..127
# Error with file:  wildthing06.mid
#  Error:  Could not decode key with 1 flats and mode 39
# Error with file:  gloria_estefan-let_it_snow.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  beet5m3.mid
#  Error:  Could not decode key with 10 sharps and mode 0
# Error with file:  TheresAPlace.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  RedemptionSong.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Maroon 5 ft. Christina Aguilera - Moves Like Jagger.mid
#  Error:  list index out of range
# Error with file:  Splish-Splash.mid
#  Error:  data byte must be in range 0..127
# Error with file:  f7d3s03r.mid
#  Error:  data byte must be in range 0..127
# Error with file:  forgotten.mid
#  Error:
# Error with file:  The Thrillseekers - Dreaming Of You (Flutlicht Remix).mid
#  Error:  list index out of range
# Error with file:  Dgate.mid
#  Error:
# Error with file:  marioinsnow.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Swanky_Tunes_-_XOXO_(Original_Mix)__djrenco_20110616210518.mid
#  Error:  list index out of range
# Error with file:  bonjovi_itsmylife.mid
#  Error:
# Error with file:  OnEaglesWings.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  radiosng.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  CircleOfLife2.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  ELVIS_PRESLEY__Dont_Be_Cruel.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Aaron_Neville_-_Tell_It_Like_It_Is.mid
#  Error:  data byte must be in range 0..127
# 23000 117102
# Error with file:  brand_3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Born-To-Be-Wild-3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Lufia  The Fortress of Doom - Ending.mid
#  Error:  data byte must be in range 0..127
# Error with file:  4tyoume.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Armin_van_Buuren_-_Drowning_(Avicii_Unnamed_Remix)__djrenco_20110413194122.mid
#  Error:  list index out of range
# Error with file:  TRAVIS.Driftwood.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  rndmngt.mid
#  Error:  Could not decode key with 6 flats and mode 255
# Error with file:  MariaElena.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Saving-All-My-Love-For-You-3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  topgun03.mid
#  Error:
# Error with file:  ASIA.Don't cry K.mid
#  Error:  data byte must be in range 0..127
# Error with file:  John Steenbergen - Circle Of Life.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  EndreH - Teardrop.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  house2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  sir_swlk.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Spear K - K Style.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  PennsylvaniaPolka.mid
#  Error:  Could not decode key with 1 flats and mode 161
# Error with file:  lvl13.mid
#  Error:  data byte must be in range 0..127
# Error with file:  DION.Where does my heart beat now.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  SMSS_BrainsOverBrawn_MercurysTheme3_SNES_.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Sam G - Leave Me Alone.mid
#  Error:  list index out of range
# Error with file:  Banjo kazooie - Gobis Valley.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  SailAway.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Milk Inc - Run.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  No_woman.mid
# ...
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  dgate045.mid
#  Error:
# Error with file:  DNBSpeedFreakmixdeath13.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  KeeperoftheStars3.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  moonlightsonata2.mid
#  Error:
# Error with file:  Laloca.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Guns_n_Roses_-_Since_I_Don't_Have_You.mid
#  Error:
# Error with file:  thomas.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  I'm-Every-Woman-1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  ff1cave2gurgx.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Nelly - Country Grammar.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Led_Zeppelin_-_In_the_Evening.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Radiohead - Airbag.mid
#  Error:  data byte must be in range 0..127
# Error with file:  SeptemberSong.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  ifyou1.mid
#  Error:
# Error with file:  indig.mid
#  Error:  data byte must be in range 0..127
# Error with file:  festov.mid
#  Error:  Could not decode key with 8 sharps and mode 0
# Error with file:  E-Type_-_Life__Mayank_20070613200515.mid
#  Error:  MThd not found. Probably not a MIDI file
# 109000 117102
# Error with file:  pinkpant1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  radicalMINDOWS.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  topgun2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  di_trong_huong_tram_(a).mid
#  Error:  data byte must be in range 0..127
# Error with file:  Noriko_Sakai_Yumebouken.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Storaged.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Mosaico_Billos_Caracas_1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  EMNextTimeIFall.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  idontb.mid
#  Error:
# Error with file:  Nirvana_-_Been_A_Son.mid
#  Error:  running status without last_status
# Error with file:  Mysterious.mid
#  Error:
# Error with file:  interf.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  topsy2.mid
#  Error:  Could not decode key with 5 flats and mode 162
# Error with file:  style.mid
#  Error:  Could not decode key with 4 flats and mode 255
# Error with file:  Sonic Unleashed - Apotos Day Mission.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Radio-ga.mid
#  Error:  data byte must be in range 0..127
# Error with file:  thedance06.mid
#  Error:  data byte must be in range 0..127
# Error with file:  contry_v.mid
#  Error:  Could not decode key with 8 flats and mode 0
# Error with file:  GODSMACK.Moon baby.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/GODSMACK.Moon baby.mid'
# Error with file:  weddingsong3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  soulrefrain.mid
#  Error:
# Error with file:  ba2.mid
#  Error:  MThd not found. Probably not a MIDI file
# 110000 117102
# Error with file:  Toni Braxton - Make My Heart (Avicii's Replacer Mix).mid
#  Error:  list index out of range
# Error with file:  ConquestOfParadise2.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Banjo kazooie - BattleWith GruntyEasyversion.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  beet54s.mid
#  Error:  running status without last_status
# Error with file:  varipaga.mid
#  Error:
# Error with file:  lookin_out_my_back_door.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  takethemoneyandrun.mid
#  Error:
# Error with file:  abba-just_like_that.mid
#  Error:  data byte must be in range 0..127
# Error with file:  FromADistance4.mid
#  Error:  data byte must be in range 0..127
# Error with file:  wishupon3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Paul van Dyk ft Vega 4 - Times Of Our Lives.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  myworld2.mid
#  Error:
# Error with file:  winter6.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  donutsong.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  miley_cyrus-party_in_the_usa.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Shaun Baker - Bakerman (Funktune Remix).mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  rustle.mid
#  Error:  data byte must be in range 0..127
# 111000 117102
# Error with file:  tribamer.mid
#  Error:
# Error with file:  spice.mid
#  Error:
# Error with file:  mthuo74c.mid
#  Error:  data byte must be in range 0..127
# Error with file:  always05.mid
#  Error:  data byte must be in range 0..127
# Error with file:  alone06.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  diamnd.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  led_zeppelin-ramble_on.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/led_zeppelin-ramble_on.mid'
# Error with file:  Mango_-_Kites__John_20091113102941.mid
#  Error:  list index out of range
# Error with file:  Ik-Zal-Er-Altijd-Voor-Je-Zijn.mid
#  Error:  data byte must be in range 0..127
# Error with file:  foever.mid
#  Error:  data byte must be in range 0..127
# Error with file:  envio__for_you__the_blizzard_remix__djrenco.mid
#  Error:  list index out of range
# Error with file:  story.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/192/story.mid'
# Error with file:  charlotte2.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  mo_trong_hoang_vu.mid
#  Error:  data byte must be in range 0..127
# Error with file:  SPEARK_astromon.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  DancetotheMusic.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Vampire Princess Miyu - Promise.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Death 13 - Drum & Basser (Digital Plug Mix).mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Il-Silenzio-1.mid
#  Error:  Could not decode key with 14 sharps and mode 78
# Error with file:  Bomfunk_MCs_-_Uprocking_Beats.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Elfship.mid
#  Error:
# Error with file:  Glinkl.mid
#  Error:  data byte must be in range 0..127
# Error with file:  When-Sunny-Gets-Blue.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Godsmack - Moon Baby.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/Godsmack - Moon Baby.mid'
# Error with file:  ah.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  healing3.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Laser Inc - Det Var En Gng En Fgel (Munkie Remix).mid
#  Error:  list index out of range
# 112000 117102
# Error with file:  blade.mid
#  Error:
# Error with file:  c04014.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  san_ga_chi_co_mot_nguoi_(b).mid
#  Error:  data byte must be in range 0..127
# Error with file:  Theo-Wir-Fahr'n-Nach-Lodz-1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Links_2-3-4.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/Links_2-3-4.mid'
# Error with file:  Carulli_Concerto_Flauto_Chitarra_Orchestra_Allegro.mid
#  Error:  data byte must be in range 0..127
# Error with file:  MauroPicotto_-_IguanaMegavoicesRemix__Djajb_20130129025054.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Journey_-_Any_Way_You_Want_It.mid
#  Error:  data byte must be in range 0..127
# Error with file:  saintkim1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  AlfredHitchcockPresents.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  Lasgo - Alone.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  That'sTheWayILikeIt.mid
#  Error:  data byte must be in range 0..127
# Error with file:  SadBGM1.mid
#  Error:  Could not decode key with 4 flats and mode 255
# Error with file:  thebulls.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Noriko_Sakai_Namida_Iro.mid
#  Error:  running status without last_status
# Error with file:  marisa_monte-ainda_lembro.mid
#  Error:
# 113000 117102
# Error with file:  askimisirgibi.mid
#  Error:  data byte must be in range 0..127
# Error with file:  smusic15.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  shotinthedark.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Armin van Buuren - Drowning (Avicii Unnamed Remix).mid
#  Error:  list index out of range
# Error with file:  oldchow.mid
#  Error:
# Error with file:  prmchick.mid
#  Error:  Could not decode key with 1 flats and mode 255
# Error with file:  MyFunnyValentine.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  heyjude03.mid
#  Error:
# Error with file:  D_queen.mid
#  Error:  data byte must be in range 0..127
# Error with file:  LL Cool J - Hey Lover.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Imsohappy.mid
#  Error:  data byte must be in range 0..127
# Error with file:  kordance.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Special D - Dust To Dust.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Schutzenliesl-1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Drum Data - D&B Demo.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  LawAndOrder.mid
#  Error:  data byte must be in range 0..127
# Error with file:  montygot.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Tonight-I-Celebrate-My-Love-For-You.mid
#  Error:  data byte must be in range 0..127
# Error with file:  qua_song.mid
#  Error:  data byte must be in range 0..127
# Error with file:  sarah_connor-from_zero_to_hero.mid
#  Error:
# Error with file:  haru.mid
#  Error:  data byte must be in range 0..127
# Error with file:  tinh_khuc_vang.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Airscape - L?Esperanza.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Ferry Corsten - Made Of Love.mid
#  Error:  list index out of range
# 114000 117102
# Error with file:  Mauro Picotto - Iguana.mid
#  Error:  data byte must be in range 0..127
# Error with file:  sum_41-crazy_amanda.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/sum_41-crazy_amanda.mid'
# Error with file:  system_of_a_down-toxicity.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  bemyvision.mid
#  Error:
# Error with file:  Juno - UMMU-5.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  WaitVain.mid
#  Error:  data byte must be in range 0..127
# Error with file:  savequen.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  alifesochanged2.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Night-Birds-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  ruah.mid
#  Error:  data byte must be in range 0..127
# Error with file:  nightmare3.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Gangsta's-Paradise-2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  masterb.mid
#  Error:
# Error with file:  ozzy02.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  lesson1.mid
#  Error:
# Error with file:  93.mid
#  Error:  Could not decode key with 4 flats and mode 255
# Error with file:  sometimes2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  balloons.mid
#  Error:  list index out of range
# Error with file:  Somewhere_I_Belong_2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  fav.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  MauroPicotto_-_LikeThisLikeThat__Unknown_20130129024735.mid
#  Error:  data byte must be in range 0..127
# Error with file:  God_Put_A_Smile_Upon_Your_Face_2.mid
#  Error:
# 115000 117102
# Error with file:  wayitis1.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  batt.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Skurvash.mid
#  Error:
# Error with file:  Promenade-5-Marketplace-At-Limoges-Catacombs-Skulls.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  starwar3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  I've-Been-Looking-For-Freedom-1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Blue_Collar_Man_1.mid
#  Error:  data byte must be in range 0..127
# Error with file:  always04.mid
#  Error:  wrong number of bytes for tune_request message
# Error with file:  canthelp2.mid
#  Error:
# Error with file:  dreamsharer_litl_angels.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  Gui Boratto - The Rivington.mid
#  Error:  list index out of range
# Error with file:  mthuo74b.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Stairway-To-Heaven-3.mid
#  Error:  data byte must be in range 0..127
# Error with file:  THE SMASHING PUMPKINS.Perfect.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/192/THE SMASHING PUMPKINS.Perfect.mid'
# Error with file:  gausthemeff3.mid
#  Error:
# Error with file:  Andy Moor vs. Orkidea - Yearzero.mid
#  Error:  list index out of range
# Error with file:  Zzunknow.mid
#  Error:
# Error with file:  everybreath03.mid
#  Error:  Could not decode key with 3 flats and mode 255
# Error with file:  Nirvana - Son Of A Gun.mid
#  Error:  no MTrk header at start of track
# Error with file:  One_Last_Breath_2.mid
#  Error:  data byte must be in range 0..127
# Error with file:  twinkle2.mid
#  Error:  MThd not found. Probably not a MIDI file
# 116000 117102
# Error with file:  Movie_Themes_-_Blade_Runner_-_by_Vangelis.mid
#  Error:  data byte must be in range 0..127
# Error with file:  gp-ice.mid
#  Error:  data byte must be in range 0..127
# Error with file:  postma.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Leventina - Night Shift.mid
#  Error:  list index out of range
# Error with file:  fantasmic3.mid
#  Error:
# Error with file:  littleme.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Deaddwrf.mid
#  Error:
# Error with file:  Topmodelz_-_Your_Love__Helldude__John_20080303122916.mid
#  Error:  list index out of range
# Error with file:  Wisdom_Of_The_Kings.mid
#  Error:  Could not decode key with 78 sharps and mode 159
# Error with file:  faded.mid
#  Error:  Could not decode key with 2 flats and mode 161
# Error with file:  Spear K - In My Mind.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  unchain3.mid
#  Error:
# Error with file:  Underneath_the_stars.mid
#  Error:
# Error with file:  korn-earache_my_eye.mid
#  Error:  [Errno 2] No such file or directory: '/Users/edlgg/repos/dissertation/midis/v3/no_control_change/0_vel/120/korn-earache_my_eye.mid'
# Error with file:  puff09.mid
#  Error:  Could not decode key with 2 flats and mode 255
# Error with file:  MoonMix.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  valentine04.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  start_game.mid
#  Error:  data byte must be in range 0..127
# Error with file:  boretus.mid
#  Error:  data byte must be in range 0..127
# Error with file:  Wippenberg - Pong (Tocadisco Remix).mid
#  Error:  list index out of range
# Error with file:  gotpics.mid
#  Error:  MThd not found. Probably not a MIDI file
# Error with file:  sf2dejay.mid
#  Error:  data byte must be in range 0..127
# 117000 117102
